# %% [markdown]
# # Todo
# ###

# %% [markdown]
# # Load data

# %%
api_key = "AIzaSyDZ7CJ-S0k-zOYa_rXafThaHxjHrC3f4Hk"

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./exports/clustered_locations.csv")

df.tail()
# Out:
#                         Category                  Location  Category Encoded  \
# 62  Michelin-Starred Restaurants                 Acquolina                 4
# 63  Michelin-Starred Restaurants                      Moma                 4
# 64  Michelin-Starred Restaurants   Per Me Giulio Terrinoni                 4
# 65  Michelin-Starred Restaurants                 Marzapane                 4
# 66  Michelin-Starred Restaurants  Ristorante Oliver Glowig                 4
#
#           Lat       Long                                         Open hours  \
# 62  41.908768  12.475572  ['Monday: Closed', 'Tuesday: 7:00\u2009–\u2009...
# 63  41.905647  12.490806  ['Monday: 12:30\u2009–\u20093:00\u202fPM, 7:30...
# 64  41.897325  12.467529  ['Monday: 12:30\u2009–\u20092:00\u202fPM, 7:00...
# 65  41.914077  12.475073  ['Monday: 12:30\u2009–\u20092:00\u202fPM, 7:00...
# 66  41.913900  12.472861  ['Monday: 6:00\u2009–\u200911:00\u202fPM', 'Tu...
#
# ...

# %%
bnb = pd.read_csv("./exports/bnb_optimized.csv")
bnb.head()
# Out:
#                                                 Name  \
# 0                 Snow White in the Tiberina Island.
# 1                     Brand New Attic in Trastevere!
# 2  Boutique Domus Ripetta  Close SpanishTreviPant...
# 3                        Art Apartment in Trastevere
# 4                         In the heart of Trastevere
#
#                                    Listing URL    Price  Beds  Baths  \
# 0            https://airbnb.com/rooms/10980286  12655.0     1      2
# 1  https://airbnb.com/rooms/788246879857710724  10364.0     4      2
# 2  https://airbnb.com/rooms/827996926286851122   9888.0     3      2
# 3            https://airbnb.com/rooms/53824805   7594.0     2      2
# 4            https://airbnb.com/rooms/14010875  14360.0     3      2
#
#    Bedrooms  Average Rating  Number of Reviews  Cleanliness Rating   Latitude  \
# 0         2            4.84                305                 4.9  41.892010
# ...

# %%
df_cluster = df[(df['cluster'] == 2) & (df['Category Encoded'] < 4)]
df_cluster
# Out:
#                     Category                   Location  Category Encoded  \
# 2            Must-See Sights               The Pantheon                 0
# 9            Must-See Sights              Piazza Navona                 0
# 10           Must-See Sights            Campo de' Fiori                 0
# 22                  Churches  Santa Maria in Trastevere                 1
# 26                  Churches     San Luigi dei Francesi                 1
# 30                  Churches  Santa Maria sopra Minerva                 1
# 32                  Churches     Santa Maria della Pace                 1
# 35             Art Galleries            Palazzo Altemps                 2
# 36             Art Galleries             Galleria Spada                 2
# 39             Art Galleries            Villa Farnesina                 2
# 40             Art Galleries              Museo di Roma                 2
# 49  Bib Gourmand Restaurants     Osteria delle Coppelle                 3
# ...

# %% [markdown]
# # Plot

# %%
import matplotlib.pyplot as plt

colors = {0: "red", 1: "red", 2: "red", 3: "green"}

plt.figure(figsize=(8,8))  # Create a square graph
plt.scatter(
    df_cluster["Long_rad"],
    df_cluster["Lat_rad"],
    c=df_cluster["Category Encoded"].map(colors),
)
for i, txt in enumerate(df_cluster["Location"]):
    plt.annotate(txt, (df_cluster["Long_rad"].iloc[i], df_cluster["Lat_rad"].iloc[i]))
plt.show()

# %%
df_centered = (
    df_cluster[["Lat_rad", "Long_rad"]] - df_cluster[["Lat_rad", "Long_rad"]].mean()
)
df_centered = df_centered * 10000
plt.figure(figsize=(8, 8))
plt.scatter(
    df_centered["Long_rad"],
    df_centered["Lat_rad"]
)
plt.show()

# %%
df_centered
# Out:
#      Lat_rad  Long_rad
# 2   0.240319  0.592988
# 9   0.336748 -0.070010
# 10 -0.318378 -0.222237
# 22 -1.355802 -0.665289
# 26  0.419355  0.233398
# 30  0.131760  0.793649
# 32  0.457490 -0.318405
# 35  0.673806 -0.056780
# 36 -0.528917 -0.271089
# 39 -0.634335 -1.080102
# 40  0.055349 -0.131114
# 49  0.648272  0.451966
# 50  0.818826  0.301710
# 54 -0.519737  0.133757
# 55 -0.424756  0.307557

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_scaled = pd.DataFrame(
    scaler.fit_transform(df_centered), columns=["Lat_rad", "Long_rad"]
)

# %%
cov = df_centered[["Long_rad","Lat_rad"]].cov()
cov
# Out:
#           Long_rad   Lat_rad
# Long_rad  0.235899  0.162241
# Lat_rad   0.162241  0.370980

# %%
df_centered
# Out:
#      Lat_rad  Long_rad
# 2   0.240319  0.592988
# 9   0.336748 -0.070010
# 10 -0.318378 -0.222237
# 22 -1.355802 -0.665289
# 26  0.419355  0.233398
# 30  0.131760  0.793649
# 32  0.457490 -0.318405
# 35  0.673806 -0.056780
# 36 -0.528917 -0.271089
# 39 -0.634335 -1.080102
# 40  0.055349 -0.131114
# 49  0.648272  0.451966
# 50  0.818826  0.301710
# 54 -0.519737  0.133757
# 55 -0.424756  0.307557

# %%
# Performing SVD
U, s, Vt = np.linalg.svd(df_centered.cov())
print(U)
# Transform the points
df_transformed = pd.DataFrame(np.dot(df_centered, U), columns=["y", "x"])

# Plot the transformed points
plt.scatter(df_transformed["y"], df_transformed["x"], alpha=0.7, color="red")
plt.title("Transformed Points after SVD")
plt.xlabel("x")
plt.ylabel("y")
plt.axis("equal")
plt.show()
# Out:
# [[-0.83196364 -0.55483015]
#  [-0.55483015  0.83196364]]

# %%
import requests


def get_distance_matrix(coordinates, api_key, mode="walking"):
    n = len(coordinates)
    distance_matrix = np.zeros((n, n))
    distance_matrix_url = "https://maps.googleapis.com/maps/api/distancematrix/json"

    for i in range(n):
        origins = [coordinates[i]]
        destinations = coordinates[:i] + coordinates[i + 1 :]

        params = {
            "origins": "|".join(origins),
            "destinations": "|".join(destinations),
            "mode": mode,
            "key": api_key,
        }

        response = requests.get(distance_matrix_url, params=params)
        data = response.json()

        if data["status"] == "OK":
            for j, row in enumerate(data["rows"][0]["elements"]):
                if j >= i:
                    j += 1  # Adjust index because we skipped i in destinations
                if row["status"] == "OK":
                    distance_matrix[i][j] = row["distance"]["value"]
                    distance_matrix[j][i] = row["distance"]["value"]
                else:
                    distance_matrix[i][j] = np.inf
                    distance_matrix[j][i] = np.inf
        else:
            print("Error:", data["status"])

    return distance_matrix

# %%
destinations = [f"{row.Lat},{row.Long}" for row in df_cluster.itertuples()]

# %%
destinations
# Out:
# ['41.8986108,12.4768729',
#  '41.8991633,12.4730742',
#  '41.89540969999999,12.472202',
#  '41.8894657,12.4696635',
#  '41.8996366,12.4748126',
#  '41.8979888,12.4780226',
#  '41.8998551,12.471651',
#  '41.9010945,12.47315',
#  '41.89420339999999,12.4719221',
#  '41.89359939999999,12.4672868',
#  '41.897551,12.4727241',
#  '41.9009482,12.4760649',
#  '41.9019254,12.475204',
#  '41.894256,12.4742417',
#  '41.8948002,12.4752375']

# %%
walking_matrix = get_distance_matrix(destinations, api_key)

# %%
print(walking_matrix)
# Out:
# [[   0.  386.  675. 1436.  224.  142.  574.  508.  781. 1560.  490.  344.
#    488.  677.  558.]
#  [ 386.    0.  518. 1397.  218.  553.  188.  348.  685. 1343.  274.  450.
#    472.  634.  633.]
#  [ 675.  518.    0.  886.  692.  703.  632.  830.  169.  931.  301.  925.
#    946.  214.  335.]
#  [1436. 1397.  886.    0. 1551. 1483. 1514. 1711.  747.  588. 1182. 1780.
#   1805.  839. 1024.]
#  [ 224.  218.  692. 1551.    0.  423.  396.  284.  815. 1561.  481.  242.
#    264.  712.  711.]
#  [ 142.  553.  703. 1483.  423.    0.  740.  701.  809. 1588.  640.  493.
#    681.  706.  623.]
#  [ 574.  188.  632. 1514.  396.  740.    0.  310.  799. 1233.  332.  534.
#    538.  774.  773.]
#  [ 508.  348.  830. 1711.  284.  701.  310.    0.  997. 1547.  510.  333.
#    226.  941.  940.]
#  [ 781.  685.  169.  747.  815.  809.  799.  997.    0.  791.  465. 1048.
#   1070.  250.  370.]
#  [1560. 1343.  931.  588. 1561. 1588. 1233. 1547.  791.    0. 1256. 1804.
#   1775.  882. 1003.]
# ...

# %%
walking_matrix
# Out:
# array([[   0.,  386.,  675., 1436.,  224.,  142.,  574.,  508.,  781.,
#         1560.,  490.,  344.,  488.,  677.,  558.],
#        [ 386.,    0.,  518., 1397.,  218.,  553.,  188.,  348.,  685.,
#         1343.,  274.,  450.,  472.,  634.,  633.],
#        [ 675.,  518.,    0.,  886.,  692.,  703.,  632.,  830.,  169.,
#          931.,  301.,  925.,  946.,  214.,  335.],
#        [1436., 1397.,  886.,    0., 1551., 1483., 1514., 1711.,  747.,
#          588., 1182., 1780., 1805.,  839., 1024.],
#        [ 224.,  218.,  692., 1551.,    0.,  423.,  396.,  284.,  815.,
#         1561.,  481.,  242.,  264.,  712.,  711.],
#        [ 142.,  553.,  703., 1483.,  423.,    0.,  740.,  701.,  809.,
#         1588.,  640.,  493.,  681.,  706.,  623.],
#        [ 574.,  188.,  632., 1514.,  396.,  740.,    0.,  310.,  799.,
#         1233.,  332.,  534.,  538.,  774.,  773.],
#        [ 508.,  348.,  830., 1711.,  284.,  701.,  310.,    0.,  997.,
# ...

# %%
# !pip install ortools
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 2.4 MB/s eta 0:00:00m eta 0:00:010:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 2.0 MB/s eta 0:00:00MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.2/394.2 kB 2.5 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# ...

# %%
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp


def create_data_model(distance_matrix):
    """Stores the data for the problem."""
    data = {}
    data["distance_matrix"] = distance_matrix
    data["num_vehicles"] = 1  # For TSP, the number of vehicles is 1
    data["depot"] = 5  # Starting and ending at the first node
    return data


def main(distance_matrix):
    # Instantiate the data problem.
    data = create_data_model(distance_matrix)

    # Create the routing index manager.
    manager = pywrapcp.RoutingIndexManager(
        len(data["distance_matrix"]), data["num_vehicles"], data["depot"]
    )

    # Create Routing Model.
    routing = pywrapcp.RoutingModel(manager)

    # Create and register a transit callback.
    def distance_callback(from_index, to_index):
        """Returns the distance between the two nodes."""
        # Convert from routing variable Index to distance matrix NodeIndex.
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        return data["distance_matrix"][from_node][to_node]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    # Define cost of each arc.
    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    # Setting first solution heuristic.
    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC
    )

    # Solve the problem.
    solution = routing.SolveWithParameters(search_parameters)

    # Print solution on console.
    if solution:
        return print_solution(manager, routing, solution)
    return solution


def print_solution(manager, routing, solution):
    """Prints solution on console."""
    print("Objective: {} miles".format(solution.ObjectiveValue()))
    index = routing.Start(0)
    plan_output = "Route for vehicle 0:\n"
    route_distance = 0
    route = []
    while not routing.IsEnd(index):
        plan_output += " {} ->".format(manager.IndexToNode(index))
        route.append(manager.IndexToNode(index))
        previous_index = index
        index = solution.Value(routing.NextVar(index))
        route_distance += routing.GetArcCostForVehicle(previous_index, index, 0)
    plan_output += " {}\n".format(manager.IndexToNode(index))
    print(plan_output)
    print("Route distance: {}miles\n".format(route_distance))
    return route


# Assuming distance_matrix is already defined
solution = main(walking_matrix)
# Out:
# Objective: 0 miles
# Route for vehicle 0:
#  5 -> 14 -> 13 -> 12 -> 11 -> 10 -> 9 -> 8 -> 7 -> 6 -> 4 -> 3 -> 2 -> 1 -> 0 -> 5
#
# Route distance: 0miles

# %%
df_cluster = df_cluster.reset_index(drop=True)
df_cluster
# Out:
#            Category                   Location  Category Encoded        Lat  \
# 0   Must-See Sights               The Pantheon                 0  41.898611
# 1   Must-See Sights              Piazza Navona                 0  41.899163
# 2   Must-See Sights            Campo de' Fiori                 0  41.895410
# 3          Churches  Santa Maria in Trastevere                 1  41.889466
# 4          Churches     San Luigi dei Francesi                 1  41.899637
# 5          Churches  Santa Maria sopra Minerva                 1  41.897989
# 6          Churches     Santa Maria della Pace                 1  41.899855
# 7     Art Galleries            Palazzo Altemps                 2  41.901094
# 8     Art Galleries             Galleria Spada                 2  41.894203
# 9     Art Galleries            Villa Farnesina                 2  41.893599
# 10    Art Galleries              Museo di Roma                 2  41.897551
#
# ...

# %%
solution
import matplotlib.pyplot as plt

# Assuming df_clusters is a DataFrame with the coordinates of each node
plt.scatter(df_cluster['Long_rad'], df_cluster['Lat_rad'])
for i, txt in enumerate(df_cluster['Location']):
    plt.annotate(txt, (df_cluster['Long_rad'][i], df_cluster['Lat_rad'][i]))

# Draw lines in the order of the solution
for i in range(len(solution) - 1):
    x1 = df_cluster.loc[solution[i], 'Long_rad']
    y1 = df_cluster.loc[solution[i], 'Lat_rad']
    x2 = df_cluster.loc[solution[i+1], 'Long_rad']
    y2 = df_cluster.loc[solution[i+1], 'Lat_rad']
    plt.plot([x1, x2], [y1, y2])

plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Plot the line
plt.plot(x, y)

# Display the plot
plt.show()
